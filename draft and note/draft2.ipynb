# %% [markdown]
# # Seattle and Boston airbnb customer review data process

# %% [markdown]
# This note book will describe how I process the customer review data from Seattle and Boston Airbnb.
# This notebook is more like a tutorial to help myself go through a natrual language process.

# %%
#import necessary library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import string
from nltk.corpus import stopwords
#import nltk
#nltk.download('stopwords')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
# %matplotlib inline

# %%
seattle_reviews=pd.read_csv("seattle/reviews.csv")

# %%
seattle_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
seattle_reviews.shape
# Out:
# (84849, 6)

# %%
seattle_reviews_cleaned=seattle_reviews[seattle_reviews['comments'].isnull()==False]

# %%
seattle_reviews_cleaned['length']=seattle_reviews_cleaned['comments'].apply(len)
# Out:
# C:\Users\xhc\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
seattle_reviews_cleaned['length'].plot.hist(bins=100)

# %%
seattle_reviews_cleaned[seattle_reviews_cleaned['length']==3472]['comments'].iloc[0]
# Out:
# "CURLERS - this is the perfect location when you are competing at the Granite Curling Club (GCC.)  The Heller Lake Log Cabin was not only in a better location than the local hotels but was cheaper and much nicer than the places our friends stayed this weekend.  And for larger groups there is also a house for rental on the same property.  \r\n\r\nWe flew into town for a Bonspiel (curling tournament) at the Granite Curling Club and this was the perfect location.  The club had a deal with some of the local hotels but when I looked into it they were 1) much farther away and 2) more expensive.  We were able to walk to GCC, which was only about three blocks away, while everyone else had to drive back and forth between the club and their hotel.  \r\n\r\nThe cabin is so nice and in such a great location for us that it makes the decision to return for future Bonspiels an easy one.  With there also being a house for rent on the same property we will likely have our whole team stay with us next time which will make for a much better trip while saving everyone money over the local hotel rates and save people time because they won't have to drive as far.\r\n\r\nEven if you are coming to Seattle as a tourist instead of a curler, the location is great.  Even though it is north of downtown we were able to get back and forth to the airport quickly, even with traffic on our way back.  And downtown was easily accessed by car by either the freeway or Aurora Ave and when we didn't want to take the car there are buses running straight down Aurora to both the Fremont District (think Berkeley) and downtown.  \r\n\r\nAs mentioned by others, the cabin can get a little chilly at night but it wasn't an issue at all for us.  The space heaters are enough to keep it from becoming uncomfortable and the bed was not only comfortable but very warm.  With a fridge, coffee maker, and hotplate we had almost everything we needed.  (Bring a hairdryer if you require one but be kind to the electrical system by turning off some lights and the heater before firing it up.  We had no issues but I was an electrician and advise everyone to do that even when at home.)  Although we didn't get a chance to use them, there were even fishing poles by the front door for relaxing by the lake.\r\n\r\nRoberta and Dan were wonderful hosts and we absolutely loved the Heller Lake Log Cabin.  Even though we arrived after midnight and had to depart at an odd hour in the afternoon, Roberta and Dan were so accomodating that we didn't have to worry about anything.  The direction to the cabin were spot on, which was especially nice because we arrived after dark.\r\n\r\nWe are looking forward to adding the Heller Lake Log Cabin to our regular list of fun weekend trips.  (Although it is a bit of a drive, check out Skillet Diner in Capital Hill for some incredible eats.  And if you make it to Pikes Place don't miss the mini-donut vendor who is on the street level.  For 24 hour a day dining (our first curling match started at 7am) Beth's is just a short drive south on Aurora Avenue and is a local favorite.)\r\n\r\nAll in all this was a wonderful location to stay at and we look forward to many more trips to this property.  You simple cannot go wrong with this location and Roberta and Dan as hosts, whether you are staying for a Bonspiel, just looking for a local get-away (it was nice and quiet), or visiting in full tourist mode.  We are already checking the calendar to see when we can get back up for a visit."

# %% [markdown]
# ## remove punctuation and non-english characters

# %% [markdown]
# Now it is time to do some encoding on the comments
# Each comments contains punctuation. I want to exlcude or remove these punctuation from comments
# In addtions, the comments is a mixture of english and non-english characters. In this project, I want to deal with English comments. Therefore, texts in other language needs to be filter out.

# %% [markdown]
# here is an example to remove punctuation

# %%
# lets put the first comment to a, a will be a string
first_comment=seattle_reviews_cleaned['comments'][0]

# %%
first_comment
# Out:
# 'Cute and cozy place. Perfect location to everything! '

# %%
#remove the punctuation in the first_comment and store into nonpunc_comment
#the nonpunc_comment will be a list of string, each alphebet will be a str in this list
# space is also included as a single element in the list
nonpunc_comment=[x for x in first_comment if x not in string.punctuation]

# %%
#for example
nonpunc_comment[0:10]
# Out:
# ['C', 'u', 't', 'e', ' ', 'a', 'n', 'd', ' ', 'c']

# %%
# use .join to put all the string together. 
#""will be added between each element in this str list. 
#Since there is nothing in the "", all the element will combine together
nonpunc_comment="".join(nonpunc_comment)

# %%
nonpunc_comment
# Out:
# 'Cute and cozy place Perfect location to everything '

# %% [markdown]
# example to remove non-english texts

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\xhc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
englishwords=set(nltk.corpus.words.words())

# %%
example_mix_sentence="我很高兴 I am so happy muy contento"

# %%
non_english_example=[x for x in example_mix_sentence.split() if x.lower() in englishwords or not x.isalpha()]

# %%
non_english_example
# Out:
# ['I', 'am', 'so', 'happy']

# %% [markdown]
# ## remove stop words

# %% [markdown]
# There are some commons words, such as they, it , has and so on that exists in the comments.
# We want to remove them. In this case, we can use nltk.corpus library's stopwords

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xhc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#remove the stopwords
#make sure to use .lower(), since comments contain captial words
clean_comment=[x for x in nonpunc_comment.split() if x.lower() not in stopwords.words("english") ]

# %%
#here we go
clean_comment
# Out:
# ['Cute', 'cozy', 'place', 'Perfect', 'location', 'everything']

# %% [markdown]
# ## pack removing punctuation and stopwords together

# %%
def text_clean(comments):
    """
    input: a string
    output: a clean string
    process: remove punctuation, remove stopwords
    """
    englishwords=set(nltk.corpus.words.words())
    
    nonpunc_comment=[x for x in comments if x not in string.punctuation]
    nonpunc_comment="".join(nonpunc_comment)
    clean_comment=[x for x in nonpunc_comment.split() if x.lower() in englishwords or not x.isalpha() or not stopwords.words("english") ]
    
    return clean_comment

# %% [markdown]
# text_clean can not work on nan value, so when apply it to a df, the column that contain text has to be nan free

# %%
def data_text_clean(df,columns):
    """
    input: df       dataframe
           columns  the column name that contains text string
    output: cleaned dataframe with cleaned text
            removed nan in columns with text string
            apply text_clean function to remove punctuation, stopwords
    """
    
    newdf=df[df[columns].isnull()==False]
    newdf[columns]=newdf[columns].apply(text_clean)
    return newdf

# %% [markdown]
# now apply the clean function to the dataframe

# %%
seattle_reviews_cleaned=data_text_clean(seattle_reviews,'comments')
# Out:
# C:\Users\xhc\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# save the cleaned data to file, since it takes a while to process the data

# %%
seattle_reviews_cleaned.to_csv('seattle_reviews_cleaned.csv', sep=';', index = False)

# %% [markdown]
# load the check point savved data

# %%
seattle_reviews_cleaned=pd.read_csv("seattle_reviews_cleaned.csv", sep=';')

# %%
seattle_reviews_cleaned["comments"]
# Out:
# 0        ['Cute', 'cozy', 'place', 'Perfect', 'location...
# 1        ['Kelly', 'great', 'room', 'central', 'locatio...
# 2        ['spacious', 'apartment', 'great', 'neighborho...
# 3        ['Close', 'Seattle', 'Center', 'offer', 'balle...
# 4        ['Kelly', 'great', 'host', 'accommodating', 'g...
# 5        ['Kelly', 'great', 'place', 'great', 'looking'...
# 6        ['Kelly', 'great', 'nice', 'neighborhood', 'pl...
# 7        ['hola', 'bnb', 'erz', 'left', 'Seattle', 'sim...
# 8        ['Kellys', 'place', 'conveniently', 'located',...
# 9        ['place', 'really', 'nice', 'clean', 'importan...
# 10       ['place', 'really', 'nice', 'clean', 'quiet', ...
# 11       ['listing', 'exactly', 'described', 'Kellys', ...
# 12       ['welcoming', 'nicer', 'place', 'live', 'Seatt...
# 13       ['Great', 'location', 'great', 'price', 'great...
# 14       ['Staying', 'Kellys', 'easy', 'location', 'blo...
# 15       ['Kelly', 'amazing', 'host', 'made', 'stay', '...
# 16       ['Despite', 'late', 'booking', 'request', 'Rac...
# 17       ['Rachel', 'Jon', 'nice', 'house', 'closed', '...
# 18       ['Rachel', 'Jon', 'perfect', 'hosts', 'us', 's...
# 19       ['house', 'delightful', 'bright', 'place', 'st...
# 20       ['Beautiful', 'place', 'nice', 'neighborhood',...
# 21       ['Super', 'cozy', 'home', 'Located', 'near', '...
# 22       ['Cute', 'house', 'Rachel', 'Jon', 'super', 'n...
# 23       ['Rachel', 'Jon', 'really', 'great', 'hosts', ...
# 24       ['house', 'easy', 'locate', 'arrangement', 'ge...
# 25       ['Rachel', 'Jon', 'obliging', 'hosts', 'super'...
# 26       ['great', 'stay', 'Rachel', 'Jons', 'accommoda...
# 27       ['amazing', 'time', 'felt', 'welcome', 'Rachel...
# 28       ['easy', 'get', 'touch', 'Rachel', 'book', 'sp...
# 29       ['Rachel', 'Jons', 'home', 'beautiful', 'inspi...
#                                ...
# 84801    ['good', 'experience', 'staying', 'Michael', '...
# 84802    ['great', 'place', 'stay', 'First', 'well', 'l...
# 84803    ['Awesome', 'location', 'price', 'apartment', ...
# 84804         ['Nice', 'neighbourhood', 'warm', 'welcome']
# 84805    ['Great', 'location', 'little', 'scared', 'ent...
# 84806    ['boyfriend', 'great', 'experience', 'staying'...
# 84807    ['great', 'stay', 'Michael', 'Leah', 'made', '...
# 84808    ['good', 'stay', 'Michael', 'Leah', 'provided'...
# 84809    ['big', 'city', 'hard', 'find', 'clean', 'room...
# 84810    ['searching', 'place', 'last', 'minute', 'thre...
# 84811              ['nice', 'apartment', 'clean', 'quite']
# 84812    ['location', 'super', 'convenient', 'state', '...
# 84813    ['apartment', 'great', 'location', 'easy', 'wa...
# 84814    ['Absolutely', 'perfect', 'stay', 'Doug', 'Reb...
# 84815    ['Excellent', 'room', 'attentive', 'property',...
# 84816    ['Great', 'clean', 'place', 'perfect', 'locati...
# 84817    ['amazing', 'place', 'stay', 'Seattle', 'girlf...
# 84818    ['excellent', 'stay', 'Seattle', 'Suites', 'ap...
# 84819    ['apartment', 'clean', 'accurate', 'descriptio...
# 84820    ['warmly', 'greeted', 'Doug', 'time', 'agreed'...
# 84821    ['apartment', 'clean', 'tidy', 'described', 'D...
# 84822    ['7', 'people', 'rebeccas', 'two', '2bed', 'ap...
# 84823    ['Great', 'place', 'middle', 'city', 'Easy', '...
# 84824    ['loved', 'close', 'Convention', 'Center', 'co...
# 84825    ['Comfortability', 'upon', 'arrival', 'everyth...
# 84826    ['description', 'pictures', 'apartment', 'exac...
# 84827    ['excellent', 'stay', 'clean', 'comfortable', ...
# 84828    ['Gran', 'ubicación', 'cerca', 'de', 'todo', '...
# 84829    ['good', 'apartement', 'clean', 'well', 'sized...
# 84830    ['Breanne', 'great', 'host', 'Check', 'easy', ...
# Name: comments, Length: 84831, dtype: object

# %% [markdown]
# ## perform count vectorization

# %% [markdown]
# ### use sklearn to perform count vectorization

# %%
comments_vectorizer=CountVectorizer()
vectorized_seattle_reviews=comments_vectorizer.fit_transform(seattle_reviews_cleaned['comments'])

# %% [markdown]
# show how mamy words are included in all vocabulary

# %%
len(comments_vectorizer.vocabulary_)
# Out:
# 54034

# %%
# the shape shows that each index will follow by a vector, the vector contains all 54034 unqiue words that appear in comments
vectorized_seattle_reviews.shape
# Out:
# (84831, 54034)

# %%
# check the sparsit: he number of zero-valued elements divided by the total number of elements 
vectorized_seattle_reviews.nnz/(vectorized_seattle_reviews.shape[0]*vectorized_seattle_reviews.shape[1])
# Out:
# 0.0006041856586968253

# %%
print(vectorized_seattle_reviews)
# Out:
#   (0, 11288)	1
#   (0, 11752)	1
#   (0, 15971)	1
#   (0, 26676)	1
#   (0, 33170)	1
#   (0, 33837)	1
#   (1, 3813)	1
#   (1, 5488)	1
#   (1, 7315)	1
#   (1, 8430)	1
#   (1, 8451)	1
#   (1, 8907)	1
#   (1, 16171)	1
#   (1, 16936)	1
#   (1, 16995)	1
#   (1, 17630)	1
#   (1, 17864)	1
#   (1, 19334)	1
#   (1, 19770)	2
#   (1, 20166)	1
#   (1, 21513)	1
#   (1, 24755)	1
#   (1, 26301)	1
#   (1, 26676)	1
#   (1, 27492)	1
#   :	:
#   (84830, 6971)	1
#   (84830, 8753)	1
#   (84830, 8800)	1
#   (84830, 9319)	1
#   (84830, 9942)	1
#   (84830, 12390)	1
#   (84830, 12688)	1
#   (84830, 14530)	1
#   (84830, 15903)	1
#   (84830, 19770)	1
#   (84830, 21803)	1
#   (84830, 24246)	1
#   (84830, 25948)	1
#   (84830, 26083)	1
#   (84830, 27019)	1
#   (84830, 29521)	1
#   (84830, 33837)	1
#   (84830, 34415)	1
#   (84830, 37626)	1
#   (84830, 38745)	1
#   (84830, 41951)	1
#   (84830, 42403)	1
#   (84830, 44668)	1
#   (84830, 45049)	1
#   (84830, 49255)	1

# %% [markdown]
# pack everyting together

# %%
def comments_vectorization(overalldf,regionaldf,col_name="comments"):
    """
    input: 
    """
    vectorizer=CountVectorizer()
    vectorizer.fit(overalldf[col_name])
    vectorized_regionaldf=vectorizer.transform(regionaldf[col_name])
    return vectorizer,vectorized_regionaldf

# %% [markdown]
# ### count frequency words

# %%
sum_comments_words=vectorized_seattle_reviews.sum(axis=0)

# %%
freq_comments_words=[(x, sum_comments_words[0,i]) for x,i in comments_vectorizer.vocabulary_.items()]

# %%
freq_comments_words
# Out:
# [('cute', 3489),
#  ('cozy', 7692),
#  ('place', 45407),
#  ('perfect', 16190),
#  ('location', 28558),
#  ('everything', 19720),
#  ('kelly', 369),
#  ('great', 60776),
#  ('room', 20704),
#  ('central', 1487),
#  ('beautiful', 9682),
#  ('building', 2943),
#  ('architecture', 62),
#  ('style', 442),
#  ('really', 16295),
#  ('like', 9993),
#  ('felt', 6540),
#  ('guite', 1),
#  ('home', 20232),
#  ('wish', 1304),
#  ('spent', 1597),
#  ('time', 17770),
#  ('went', 3066),
#  ('walk', 10618),
#  ('found', 2926),
#  ('seattle', 39526),
#  ('center', 2349),
#  ('major', 835),
#  ('food', 2936),
#  ('festival', 88),
#  ('progress', 36),
#  ('treat', 574),
#  ('visited', 569),
#  ('space', 13972),
#  ('needle', 2220),
#  ('chihuly', 135),
#  ('glass', 353),
#  ('exhibit', 32),
#  ('pikes', 1114),
#  ('market', 3671),
#  ('wow', 296),
#  ('thanks', 7361),
#  ('stay', 51984),
#  ('spacious', 4797),
#  ('apartment', 25840),
#  ('neighborhood', 18124),
#  ('kind', 3699),
#  ('didnt', 6791),
#  ('get', 11327),
#  ('meet', 3456),
#  ('always', 3436),
#  ('readily', 293),
#  ('available', 4489),
#  ('phone', 814),
#  ('believe', 234),
#  ('issue', 1226),
#  ('want', 3412),
#  ('call', 655),
#  ('finding', 692),
#  ('park', 3669),
#  ('sincerely', 54),
#  ('doubt', 194),
#  ('easy', 17939),
#  ('anywhere', 951),
#  ('residential', 921),
#  ('area', 11523),
#  ('pm', 201),
#  ('friday', 159),
#  ('close', 11783),
#  ('offer', 995),
#  ('ballet', 11),
#  ('theater', 106),
#  ('museum', 357),
#  ('restaurants', 11296),
#  ('ilk', 1),
#  ('blocks', 3124),
#  ('away', 7815),
#  ('metropolitan', 62),
#  ('probably', 818),
#  ('coolest', 104),
#  ('grocer', 15),
#  ('youll', 639),
#  ('ever', 2540),
#  ('find', 3912),
#  ('warm', 4437),
#  ('welcoming', 7545),
#  ('interesting', 1302),
#  ('talk', 884),
#  ('host', 20726),
#  ('accommodating', 6644),
#  ('coffee', 8186),
#  ('wasnt', 1735),
#  ('around', 8486),
#  ('much', 7741),
#  ('interacting', 36),
#  ('pleasant', 2718),
#  ('lot', 4216),
#  ('good', 11495),
#  ('well', 15275),
#  ('looking', 3701),
#  ('clean', 29126),
#  ('simple', 1315),
#  ('kept', 1512),
#  ('min', 1283),
#  ('bike', 599),
#  ('share', 576),
#  ('aug', 10),
#  ('2015', 54),
#  ('used', 1832),
#  ('week', 1759),
#  ('nice', 23050),
#  ('expected', 1525),
#  ('comfortable', 25044),
#  ('overall', 4066),
#  ('would', 26129),
#  ('book', 1860),
#  ('hola', 2),
#  ('bnb', 677),
#  ('erz', 1),
#  ('left', 4545),
#  ('simply', 494),
#  ('fantastic', 5120),
#  ('weekend', 2766),
#  ('small', 3787),
#  ('part', 2240),
#  ('welcome', 4699),
#  ('mat', 55),
#  ('kellys', 86),
#  ('mega', 8),
#  ('efficient', 328),
#  ('including', 1884),
#  ('precise', 39),
#  ('directionsvery', 1),
#  ('important', 442),
#  ('town', 3878),
#  ('oh', 373),
#  ('btw', 78),
#  ('cool', 2890),
#  ('50s', 10),
#  ('apt', 1390),
#  ('spot', 3540),
#  ('anything', 2534),
#  ('minimum', 44),
#  ('effort', 285),
#  ('cheers', 98),
#  ('conveniently', 1467),
#  ('located', 6555),
#  ('quiet', 12114),
#  ('street', 5936),
#  ('lower', 336),
#  ('queen', 1578),
#  ('anne', 1246),
#  ('buscab', 1),
#  ('ride', 2092),
#  ('belltown', 508),
#  ('downtown', 15698),
#  ('addition', 522),
#  ('booming', 4),
#  ('right', 6733),
#  ('alas', 14),
#  ('visiting', 3002),
#  ('job', 777),
#  ('old', 1630),
#  ('friends', 2848),
#  ('schedule', 769),
#  ('completely', 861),
#  ('full', 2622),
#  ('barely', 149),
#  ('got', 3761),
#  ('bad', 646),
#  ('seemed', 768),
#  ('aspect', 109),
#  ('moved', 257),
#  ('across', 1307),
#  ('city', 8486),
#  ('easily', 2484),
#  ('muy', 152),
#  ('limpio', 22),
#  ('espacioso', 2),
#  ('fue', 42),
#  ('agradable', 17),
#  ('lo', 56),
#  ('mas', 13),
#  ('importante', 3),
#  ('es', 278),
#  ('que', 234),
#  ('esta', 13),
#  ('cerca', 21),
#  ('de', 832),
#  ('prácticamente', 1),
#  ('todo', 61),
#  ('nos', 70),
#  ('permitió', 1),
#  ('movernos', 1),
#  ('fácilmente', 2),
#  ('por', 40),
#  ('la', 637),
#  ('cuidad', 1),
#  ('night', 7133),
#  ('linen', 90),
#  ('towels', 2544),
#  ('provided', 6074),
#  ('air', 1771),
#  ('mattress', 765),
#  ('superb', 394),
#  ('neighbourhood', 1741),
#  ('practical', 97),
#  ('cafes', 1090),
#  ('reachable', 132),
#  ('foot', 601),
#  ('30', 484),
#  ('bus', 8182),
#  ('10', 1864),
#  ('although', 2258),
#  ('working', 736),
#  ('havent', 110),
#  ('listing', 2750),
#  ('exactly', 5113),
#  ('described', 4519),
#  ('wonderful', 12231),
#  ('cleen', 1),
#  ('moment', 517),
#  ('one', 9585),
#  ('evening', 1332),
#  ('varied', 26),
#  ('us', 31834),
#  ('also', 14336),
#  ('walking', 9667),
#  ('distance', 7544),
#  ('lots', 4702),
#  ('recommend', 16449),
#  ('others', 1266),
#  ('traveling', 1169),
#  ('nicer', 384),
#  ('live', 1169),
#  ('price', 1618),
#  ('wine', 1581),
#  ('conversation', 397),
#  ('definitely', 15313),
#  ('see', 4053),
#  ('visit', 6370),
#  ('next', 6148),
#  ('staying', 11251),
#  ('block', 1904),
#  ('public', 2730),
#  ('transportation', 2084),
#  ('keys', 913),
#  ('access', 4929),
#  ('timing', 67),
#  ('extremely', 4149),
#  ('flexible', 1796),
#  ('nothing', 911),
#  ('fancy', 202),
#  ('negative', 260),
#  ('shower', 2566),
#  ('drain', 41),
#  ('amazing', 6878),
#  ('made', 12534),
#  ('pleasurable', 33),
#  ('ideal', 1288),
#  ('anyone', 3922),
#  ('highly', 8357),
#  ('recommended', 2679),
#  ('despite', 542),
#  ('late', 3184),
#  ('booking', 1157),
#  ('request', 605),
#  ('rachel', 198),
#  ('jon', 317),
#  ('responsive', 3857),
#  ('helpful', 10197),
#  ('email', 1072),
#  ('house', 22724),
#  ('wellfurnished', 60),
#  ('cat', 1153),
#  ('company', 399),
#  ('lovely', 8964),
#  ('experience', 11980),
#  ('farmhouse', 21),
#  ('closed', 265),
#  ('kitten', 19),
#  ('friendly', 9411),
#  ('hosts', 8117),
#  ('tight', 278),
#  ('checkin', 2030),
#  ('reservation', 1395),
#  ('luggages', 22),
#  ('coats', 13),
#  ('big', 2448),
#  ('closet', 802),
#  ('given', 717),
#  ('spare', 132),
#  ('key', 1426),
#  ('youre', 2371),
#  ('free', 1487),
#  ('go', 5284),
#  ('confortable', 169),
#  ('recommand', 36),
#  ('going', 2418),
#  ('delightful', 872),
#  ('bright', 988),
#  ('breakfast', 3452),
#  ('morning', 3723),
#  ('arrived', 4842),
#  ('brigette', 1),
#  ('greeted', 1290),
#  ('couple', 2932),
#  ('sleep', 2020),
#  ('super', 8009),
#  ('near', 2994),
#  ('bars', 3523),
#  ('sleeping', 925),
#  ('busy', 1204),
#  ('sightseeing', 473),
#  ('day', 6573),
#  ('love', 3402),
#  ('added', 609),
#  ('bonus', 915),
#  ('downside', 310),
#  ('needed', 10762),
#  ('extra', 1972),
#  ('wake', 237),
#  ('early', 2198),
#  ('rachels', 34),
#  ('im', 2384),
#  ('sure', 5209),
#  ('theyre', 216),
#  ('another', 1499),
#  ('bread', 377),
#  ('beverages', 174),
#  ('unfortunately', 654),
#  ('enjoy', 2220),
#  ('prompt', 937),
#  ('communication', 2956),
#  ('rooms', 1322),
#  ('relaxing', 1452),
#  ('decor', 851),
#  ('guys', 418),
#  ('immediately', 982),
#  ('ease', 403),
#  ('advertised', 1498),
#  ('know', 2427),
#  ('resources', 85),
#  ('amusing', 8),
#  ('locate', 87),
#  ('arrangement', 102),
#  ('works', 499),
#  ('fine', 1325),
#  ('even', 11105),
#  ('consistent', 36),
#  ('description', 1535),
#  ('useful', 579),
#  ('information', 2560),
#  ('takes', 764),
#  ('bit', 3358),
#  ('though', 3258),
#  ('obliging', 11),
#  ('communicative', 1050),
#  ('gave', 4611),
#  ('valuable', 67),
#  ('tips', 1367),
#  ('explore', 1644),
#  ('invited', 288),
#  ('concert', 99),
#  ('bed', 11391),
#  ('enough', 4160),
#  ('two', 5796),
#  ('furthermore', 53),
#  ('bathroom', 6991),
#  ('kitchen', 8228),
#  ('could', 8184),
#  ('complain', 90),
#  ('jons', 74),
#  ('instantly', 194),
#  ('letting', 440),
#  ('group', 932),
#  ('four', 981),
#  ('checkout', 779),
#  ('times', 1767),
#  ('charming', 2223),
#  ('within', 5640),
#  ('many', 4954),
#  ('seattles', 607),
#  ('sights', 523),
#  ('areas', 1142),
#  ('peaceful', 1447),
#  ('touch', 1539),
#  ('gracious', 2176),
#  ('shared', 1163),
#  ('getting', 2679),
#  ('ready', 1303),
#  ('work', 2961),
#  ('rest', 1092),
#  ('open', 1801),
#  ('beautifully', 1027),
#  ('decorated', 2287),
#  ('plans', 435),
#  ('lounge', 203),
#  ('especially', 2358),
#  ('kitty', 118),
#  ('quite', 3397),
#  ('weather', 894),
#  ('friend', 1792),
#  ('walked', 1926),
#  ('waterfront', 619),
#  ('took', 2432),
#  ('35', 103),
#  ('minutes', 3852),
#  ('return', 2143),
#  ('inspiring', 89),
#  ('brief', 362),
#  ('feel', 7896),
#  ('brigitte', 9),
#  ('friendliest', 62),
#  ('ive', 1134),
#  ('met', 3177),
#  ('convenient', 7000),
#  ('miles', 375),
#  ('capitol', 3347),
#  ('hill', 5350),
#  ('fun', 3073),
#  ('browsing', 26),
#  ('art', 976),
#  ('doodads', 1),
#  ('john', 969),
#  ('opened', 229),
#  ('lock', 459),
#  ('box', 322),
#  ('trouble', 623),
#  ('accessible', 1442),
#  ('fruit', 907),
#  ('nuts', 30),
#  ('guests', 2698),
#  ('greatly', 354),
#  ('appreciated', 2924),
#  ('option', 440),
#  ('sweet', 2157),
#  ('baked', 337),
#  ('homemade', 316),
#  ('cookies', 337),
#  ('tasted', 29),
#  ('hr', 29),
#  ('flight', 1097),
#  ('thank', 5357),
#  ('wifi', 1946),
#  ('list', 807),
#  ('spots', 1000),
#  ('check', 4885),
#  ('safe', 3486),
#  ('five', 661),
#  ('star', 311),
#  ('helped', 1743),
#  ('since', 2336),
#  ('later', 799),
#  ('shortly', 69),
#  ('slept', 1411),
#  ('comfortably', 575),
#  ('corner', 1082),
#  ('furnished', 1072),
#  ('chilly', 177),
#  ('private', 5638),
#  ('complimentary', 213),
#  ('drinks', 545),
#  ('dairyfree', 1),
#  ('alternative', 190),
#  ('delicious', 1308),
#  ('hazelnut', 2),
#  ('milk', 347),
#  ('lactoseintolerant', 1),
#  ('people', 4223),
#  ('able', 4543),
#  ('matched', 86),
#  ('little', 8305),
#  ('ad', 98),
#  ('ended', 600),
#  ('hanging', 365),
#  ('dreamy', 36),
#  ('awesome', 5190),
#  ('greet', 400),
#  ('provide', 814),
#  ('guidance', 67),
#  ('directions', 1309),
#  ('insider', 22),
#  ('enjoyed', 9079),
#  ('comfy', 3534),
#  ('absolutely', 3579),
#  ('welcomed', 1731),
#  ('second', 1349),
#  ('stepped', 70),
#  ('almost', 1078),
#  ('never', 2802),
#  ('insight', 79),
#  ('shaped', 9),
#  ('vacation', 956),
#  ('best', 4479),
#  ('far', 2148),
#  ('filled', 451),
#  ('lush', 131),
#  ('plants', 147),
#  ('photos', 1346),
#  ('evidence', 16),
#  ('pet', 131),
#  ('odor', 52),
#  ('hair', 402),
#  ('natural', 553),
#  ('lighting', 249),
#  ('worry', 337),
#  ('bedroom', 3539),
#  ('heavy', 133),
#  ('curtain', 101),
#  ('blocking', 21),
#  ('sun', 371),
#  ('long', 2382),
#  ('please', 216),
#  ('thing', 1609),
#  ('come', 4308),
#  ('back', 9326),
#  ('exploring', 1502),
#  ('district', 1113),
#  ('literally', 633),
#  ('everywhere', 1381),
#  ('wanted', 2510),
#  ('set', 1686),
#  ('bar', 923),
#  ('high', 939),
#  ('future', 1838),
#  ('airbnb', 7372),
#  ('experiences', 352),
#  ('try', 1004),
#  ('travel', 1469),
#  ('everyone', 891),
#  ('places', 4613),
#  ('world', 323),
#  ('heartbeat', 504),
#  ('talking', 368),
#  ('duo', 4),
#  ('amazingly', 285),
#  ('pretty', 2832),
#  ('darn', 21),
#  ('opening', 225),
#  ('short', 5288),
#  ('cab', 414),
#  ('roomhouse', 26),
#  ('mile', 681),
#  ('cheap', 314),
#  ('uber', 1259),
#  ('cats', 796),
#  ('dont', 2283),
#  ('sometimes', 264),
#  ('sensitive', 156),
#  ('way', 3843),
#  ('petting', 20),
#  ('delayed', 260),
#  ('mind', 719),
#  ('bc', 67),
#  ('loved', 7941),
#  ('longer', 1248),
#  ('plus', 2122),
#  ('dope', 9),
#  ('incredibly', 1759),
#  ('let', 2089),
#  ('drop', 471),
#  ('bags', 607),
#  ('several', 1801),
#  ('hours', 1110),
#  ('make', 5772),
#  ('pleased', 687),
#  ('adorable', 1285),
#  ('first', 8169),
#  ('totally', 1087),
#  ('contact', 1139),
#  ('arrival', 4770),
#  ('exceptionally', 253),
#  ('possible', 691),
#  ('keep', 1022),
#  ('95', 14),
#  ('degree', 61),
#  ('heat', 619),
#  ('offered', 1593),
#  ('suggestions', 1833),
#  ('yeah', 40),
#  ('cuddly', 36),
#  ('lovable', 39),
#  ('classic', 94),
#  ('middle', 705),
#  ('wave', 175),
#  ('still', 1583),
#  ('napping', 17),
#  ('midday', 14),
#  ('treats', 415),
#  ('snack', 165),
#  ('missed', 245),
#  ('paths', 178),
#  ('behold', 7),
#  ('knew', 625),
#  ('school', 158),
#  ('sipping', 41),
#  ('catching', 85),
#  ('trips', 435),
#  ('incredible', 1014),
#  ('hospitality', 1282),
#  ('hoped', 274),
#  ('shop', 1016),
#  ('fruits', 166),
#  ('labour', 10),
#  ('blueberry', 35),
#  ('picking', 108),
#  ('enjoyable', 1024),
#  ('knowing', 156),
#  ('returning', 391),
#  ('somewhere', 240),
#  ('chose', 425),
#  ('proximity', 692),
#  ('daughters', 240),
#  ('learned', 111),
#  ('use', 4220),
#  ('french', 344),
#  ('press', 208),
#  ('sunny', 388),
#  ('terms', 294),
#  ('nestled', 140),
#  ('commuting', 61),
#  ('relatively', 267),
#  ('note', 1018),
#  ('relied', 29),
#  ('cabs', 79),
#  ('lyfts', 3),
#  ('top', 1432),
#  ('brigit', 2),
#  ('utterly', 28),
#  ('spend', 1293),
#  ('recommendstay', 4),
#  ('kelli', 35),
#  ('boyfriend', 959),
#  ('run', 705),
#  ('huge', 1193),
#  ('informative', 430),
#  ('lists', 41),
#  ('highlights', 126),
#  ('beer', 567),
#  ('scene', 130),
#  ('covered', 228),
#  ('perfectly', 1871),
#  ('timers', 26),
#  ('pike', 2415),
#  ('fremont', 2400),
#  ('slightly', 212),
#  ('north', 513),
#  ('kellis', 8),
#  ('lastly', 95),
#  ('kerri', 3),
#  ('receive', 78),
#  ('views', 2292),
#  ('skyline', 225),
#  ('phenomenal', 180),
#  ('emerald', 85),
#  ('foremost', 23),
#  ('install', 12),
#  ('keybox', 8),
#  ('whole', 1799),
#  ('trip', 5680),
#  ('apparent', 51),
#  ('cares', 87),
#  ('wife', 1449),
#  ('problems', 729),
#  ('futon', 334),
#  ('folded', 27),
#  ('surprisingly', 266),
#  ('pillows', 584),
#  ('decoration', 106),
#  ('attending', 302),
#  ('pax', 50),
#  ('breeze', 832),
#  ('finally', 275),
#  ('final', 70),
#  ('dog', 1703),
#  ('bundle', 6),
#  ('reservations', 86),
#  ('music', 509),
#  ('tidy', 1179),
#  ('vegetarian', 29),
#  ('eat', 2197),
#  ('punk', 3),
#  ('turns', 67),
#  ('common', 459),
#  ('locations', 334),
#  ('either', 633),
#  ('blast', 168),
#  ('wouldnt', 740),
#  ('hesitate', 688),
#  ('heading', 233),
#  ('cutest', 119),
#  ('sign', 119),
#  ('blackboard', 9),
#  ('read', 452),
#  ('carmen', 78),
#  ('ask', 1020),
#  ('cannot', 545),
#  ('wrong', 255),
#  ('suggestion', 121),
#  ('liked', 1158),
#  ('days', 3811),
#  ('relaxed', 469),
#  ('joe', 458),
#  ('sparks', 1),
#  ('lady', 195),
#  ('problem', 2008),
#  ('record', 148),
#  ('restaurant', 1289),
#  ('recommendations', 2436),
#  ('beyond', 1189),
#  ('car', 3909),
#  ('ton', 390),
#  ('shops', 4485),
#  ('looks', 919),
#  ('pictures', 2378),
#  ('question', 474),
#  ('advice', 906),
#  ('willing', 568),
#  ('help', 2110),
#  ('text', 1069),
#  ('map', 369),
#  ('newspapers', 8),
#  ('soon', 1002),
#  ('attractions', 1574),
#  ('steps', 674),
#  ('lines', 642),
#  ('excellent', 5398),
#  ('privacy', 2477),
#  ('issues', 972),
#  ('keeps', 155),
#  ('impeccably', 187),
#  ('dustfree', 2),
#  ('asthmatic', 2),
#  ('doggy', 14),
#  ('desi', 1),
#  ('hard', 804),
#  ('leave', 1480),
#  ('advices', 71),
#  ('miss', 419),
#  ('charli', 1),
#  ('hospitable', 962),
#  ('god', 37),
#  ('bless', 13),
#  ('size', 1163),
#  ('12', 442),
#  ('accomodating', 363),
#  ('sharing', 646),
#  ('shopping', 1369),
#  ('centre', 380),
#  ('buses', 824),
#  ('knows', 227),
#  ('hints', 50),
#  ('memorable', 286),
#  ('couldnt', 2496),
#  ('better', 4028),
#  ('iconic', 22),
#  ('slew', 10),
#  ('cultural', 28),
#  ('hubs', 7),
#  ('recommendation', 273),
#  ('dishes', 438),
#  ('multiple', 369),
#  ('stops', 757),
#  ('bring', 695),
#  ('farther', 66),
#  ('example', 146),
#  ('university', 1038),
#  ('washington', 1046),
#  ('arboretum', 131),
#  ('40', 150),
#  ('sweetest', 140),
#  ('proven', 4),
#  ('scrumptious', 16),
#  ('freshly', 154),
#  ('surely', 116),
#  ('melt', 4),
#  ('heart', 1197),
#  ('accidentally', 82),
#  ('charger', 51),
#  ('boarding', 25),
#  ('plane', 104),
#  ('mailed', 39),
#  ('asked', 1549),
#  ('booked', 944),
#  ('answering', 301),
#  ('questions', 4496),
#  ('giving', 653),
#  ('sorts', 155),
#  ('mapsguides', 6),
#  ('pays', 29),
#  ('attention', 600),
#  ('details', 958),
#  ('chocolatesmints', 1),
#  ('fridge', 1905),
#  ('tea', 1373),
#  ('terrific', 785),
#  ('ex', 9),
#  ('arena', 73),
#  ('monorail', 257),
#  ('etc', 3140),
#  ('true', 491),
#  ('tv', 1869),
#  ('kick', 54),
#  ('relax', 1045),
#  ('couch', 851),
#  ('hot', 2004),
#  ('lucky', 492),
#  ('charlie', 78),
#  ('normally', 91),
#  ('courtney', 56),
#  ('ranged', 6),
#  ('indifferent', 1),
#  ('secondfloor', 3),
#  ('light', 3612),
#  ('gas', 341),
#  ('wedding', 733),
#  ('stone', 55),
#  ('welcomend', 1),
#  ('adams', 103),
#  ('douzens', 1),
#  ('squirrels', 23),
#  ('garden', 2431),
#  ('famous', 129),
#  ('freemont', 189),
#  ('troll', 120),
#  ('definetly', 54),
#  ('matthias', 1),
#  ('anna', 515),
#  ('large', 2309),
#  ('adam', 396),
#  ('odd', 166),
#  ('windows', 1554),
#  ('floor', 1886),
#  ('drapes', 9),
#  ('hardwoods', 3),
#  ('spotless', 874),
#  ('magnificent', 89),
#  ('hope', 2072),
#  ('person', 2322),
#  ('choice', 724),
#  ('stayed', 7102),
#  ('months', 327),
#  ('25', 255),
#  ('reach', 612),
#  ('busbikingwalking', 1),
#  ('20', 908),
#  ('ballard', 3938),
#  ('wallingford', 535),
#  ('last', 1966),
#  ('lunchdinner', 3),
#  ('philip', 25),
#  ('curated', 22),
#  ('selection', 378),
#  ('personal', 731),
#  ('favourites', 4),
#  ('every', 3366),
#  ('tried', 363),
#  ('sublime', 15),
#  ('jammed', 10),
#  ('together', 552),
#  ('shows', 187),
#  ('average', 87),
#  ('impersonal', 24),
#  ('sparse', 44),
#  ('maybe', 450),
#  ('werent', 533),
#  ('spending', 327),
#  ('amount', 472),
#  ('parts', 489),
#  ('ill', 699),
#  ('hit', 225),
#  ('girlfriend', 678),
#  ('nights', 2740),
#  ('real', 901),
#  ('roommate', 212),
#  ('hotel', 2353),
#  ('connect', 131),
#  ('conversations', 355),
#  ('serving', 31),
#  ('craft', 72),
#  ('chance', 1291),
#  ('delighted', 145),
#  ('mara', 4),
#  ('throughout', 1392),
#  ('arranged', 339),
#  ('walkable', 1207),
#  ('dine', 69),
#  ('take', 2546),
#  ('broadway', 388),
#  ('walkalbe', 1),
#  ('housemate', 38),
#  ('philps', 1),
#  ('ok', 495),
#  ('wont', 513),
#  ('regret', 302),
#  ('roger', 323),
#  ('latenight', 32),
#  ('responding', 339),
#  ('quickly', 1797),
#  ('plenty', 4211),
#  ('things', 4422),
#  ('我们是一家三口', 1),
#  ('可爱的女儿', 1),
#  ('夫妻二人都是中国来的访问学者', 1),
#  ('来到美丽的西雅图', 1),
#  ('住在了roger的房子里', 1),
#  ('房子位于美丽的艺术小镇fremont', 1),
#  ('有各种各样的雕塑', 1),
#  ('还有宇宙中心的路标', 1),
#  ('各种小店的橱窗也是充满特色', 1),
#  ('富有艺术气息', 1),
#  ('安静美丽的小镇', 1),
#  ('充满了秋天的味道', 1),
#  ('离西雅图市区比较近', 1),
#  ('房子位置好', 1),
#  ('能从窗户里看到rainer山', 1),
#  ('很不幸我们没有看到', 1),
#  ('fit', 698),
#  ('needs', 2525),
#  ('legs', 28),
#  ('budget', 147),
#  ('3bedroom', 5),
#  ('duplex', 75),
#  ('rumor', 1),
#  ('someone', 738),
#  ('lives', 481),
#  ('least', 348),
#  ('attached', 214),
#  ('thats', 768),
#  ('tons', 838),
#  ('rogers', 101),
#  ('warning', 80),
#  ('isnt', 566),
#  ('door', 2757),
#  ('concerned', 195),
#  ('might', 1481),
#  ('solo', 125),
#  ('sitting', 589),
#  ('rad', 55),
#  ('hes', 304),
#  ('nearby', 3433),
#  ('event', 289),
#  ('came', 2065),
#  ('sorted', 49),
#  ('view', 5941),
#  ('window', 918),
#  ('definite', 95),
#  ('canceled', 828),
#  ('21', 46),
#  ('automated', 812),
#  ('posting', 890),
#  ('miesha', 40),
#  ('term', 150),
#  ('trying', 350),
#  ('turn', 252),
#  ('else', 852),
#  ('recently', 297),
#  ('mieshas', 6),
#  ('guest', 1904),
#  ('searching', 63),
#  ('permanent', 69),
#  ('living', 2957),
#  ('situation', 334),
#  ('spa', 124),
#  ('heated', 415),
#  ('floors', 554),
#  ('towel', 197),
#  ('warmer', 107),
#  ('furniture', 505),
#  ('included', 646),
#  ('switched', 22),
#  ('chair', 268),
#  ('desk', 351),
#  ('quit', 27),
#  ('worked', 1872),
#  ('extend', 80),
#  ('ongoing', 20),
#  ('search', 67),
#  ('hand', 408),
#  ('rainiest', 1),
#  ('cant', 2033),
#  ('imagine', 345),
#  ('starting', 159),
#  ('life', 631),
#  ('farah', 37),
#  ('ben', 154),
#  ('month', 541),
#  ('easygoing', 216),
#  ('chat', 566),
#  ('that', 17),
#  ('you', 97),
#  ('re', 81),
#  ('feeling', 621),
#  ('checked', 1213),
#  ('store', 1634),
#  ('wd', 18),
#  ('stop', 1977),
#  ('parking', 7786),
#  ('entire', 1157),
#  ...]

# %%
print(sum_comments_words)
# Out:
# [[1 1 2 ... 1 1 1]]

# %% [markdown]
# ### reverse the process fro vector to words

# %% [markdown]
# now extract a single comment and see how the vectorized one looks like

# %%
#extrac the third comment
comments2=seattle_reviews_cleaned["comments"][2]

# %%
# apply the comments_vectorizer to the comments
vectorized_comments2=comments_vectorizer.transform([comments2])

# %%
# check what the vectorized one looks like. Each vector( 0,2830) represents a single words.
print(vectorized_comments2)
# Out:
#   (0, 2830)	1
#   (0, 3468)	1
#   (0, 3505)	2
#   (0, 3824)	1
#   (0, 4580)	1
#   (0, 5810)	1
#   (0, 7800)	1
#   (0, 13002)	1
#   (0, 13785)	1
#   (0, 14530)	1
#   (0, 17146)	1
#   (0, 18120)	1
#   (0, 19172)	1
#   (0, 19770)	1
#   (0, 23708)	1
#   (0, 24755)	1
#   (0, 24960)	1
#   (0, 28212)	1
#   (0, 30249)	1
#   (0, 32614)	2
#   (0, 33514)	1
#   (0, 33837)	1
#   (0, 34136)	1
#   (0, 36084)	1
#   (0, 36124)	1
#   (0, 37086)	1
#   (0, 40296)	1
#   (0, 41342)	1
#   (0, 47876)	1
#   (0, 48935)	1

# %% [markdown]
# it seems that 3505  and 32614 appear twice, I am wondering what these two words are?

# %%
comments_vectorizer.get_feature_names()[3505]
# Out:
# 'apartment'

# %%
comments_vectorizer.get_feature_names()[32614]
# Out:
# 'park'

# %% [markdown]
# ### term frequency-invserse documents frequency

# %% [markdown]
# tfidf is intended to reflect how important a word is to a document in a collection or corpus. The tf–idf value increases proportionally to the number of times a word appears in the document

# %%
tfidf_comments_transformer=TfidfTransformer()

# %%
# must use vectroized text, raw text will not work
tfidf_comments_transformer.fit(vectorized_seattle_reviews)
# Out:
# TfidfTransformer(norm='l2', smooth_idf=True, sublinear_tf=False, use_idf=True)

# %%
tfidfed_seattle_comments=tfidf_comments_transformer.transform(vectorized_seattle_reviews)

# %% [markdown]
# lets check a tfidfed comment looks like

# %%
tfidf_comments2=tfidf_comments_transformer.transform(vectorized_comments2)

# %%
print(tfidf_comments2)
# Out:
#   (0, 48935)	0.17878729327834056
#   (0, 47876)	0.14776820462399365
#   (0, 41342)	0.13395103799583064
#   (0, 40296)	0.28738536159076855
#   (0, 37086)	0.19032661741706636
#   (0, 36124)	0.09926131154458202
#   (0, 36084)	0.2297490959594253
#   (0, 34136)	0.24503745958164794
#   (0, 33837)	0.06703262833782382
#   (0, 33514)	0.19592606949685035
#   (0, 32614)	0.29102658328477093
#   (0, 30249)	0.09032151942275463
#   (0, 28212)	0.14603743651835024
#   (0, 24960)	0.14332985579177782
#   (0, 24755)	0.23440024002717316
#   (0, 23708)	0.18315151967054372
#   (0, 19770)	0.058308345347210626
#   (0, 19172)	0.10842817002944863
#   (0, 18120)	0.2521351543661006
#   (0, 17146)	0.20058977956056
#   (0, 14530)	0.09241234485536451
#   (0, 13785)	0.2443120821977109
#   (0, 13002)	0.12565138012207785
#   (0, 7800)	0.20337281516236608
#   (0, 5810)	0.23809021558716045
#   (0, 4580)	0.13789449655043964
#   (0, 3824)	0.10824095642052464
#   (0, 3505)	0.17670069546913336
#   (0, 3468)	0.1898431729064038
#   (0, 2830)	0.14712095666489394

# %%
#check inverse document frequency by searching the words
tfidf_comments_transformer.idf_[comments_vectorizer.vocabulary_['apartment']]
# Out:
# 2.56428731418519

# %%
boston_reviews=pd.read_csv("boston/reviews.csv")

# %%
boston_reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
seattle_listings=pd.read_csv("seattle/listings.csv")

# %%
seattle_listings[['number_of_reviews',
       'first_review', 'last_review', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']]
# Out:
#       number_of_reviews first_review last_review  review_scores_rating  \
# 0                   207   2011-11-01  2016-01-02                  95.0
# 1                    43   2013-08-19  2015-12-29                  96.0
# 2                    20   2014-07-30  2015-09-03                  97.0
# 3                     0          NaN         NaN                   NaN
# 4                    38   2012-07-10  2015-10-24                  92.0
# 5                    17   2015-06-11  2015-09-28                  95.0
# 6                    58   2014-01-27  2015-12-07                  99.0
# 7                   173   2013-01-03  2016-01-01                  97.0
# 8                     8   2015-06-22  2015-08-17                  97.0
# 9                    32   2014-04-27  2015-12-20                  97.0
# 10                  181   2011-07-21  2015-11-25                  97.0
# 11                    8   2015-05-06  2015-12-16                  97.0
# 12                   13   2014-11-09  2015-10-02                  98.0
# 13                    3   2015-12-16  2016-01-02                 100.0
# 14                   18   2015-06-15  2015-11-15                  98.0
# 15                    1   2015-11-25  2015-11-25                  80.0
# 16                   84   2014-06-30  2016-01-02                  95.0
# 17                   45   2015-03-16  2015-11-06                  98.0
# 18                    0          NaN         NaN                   NaN
# 19                    5   2015-07-07  2015-08-10                  85.0
# 20                    1   2016-01-03  2016-01-03                 100.0
# 21                   11   2014-09-27  2015-10-18                  84.0
# 22                    1   2015-12-01  2015-12-01                 100.0
# 23                    0          NaN         NaN                   NaN
# 24                    1   2015-07-20  2015-07-20                 100.0
# 25                    8   2015-07-04  2015-09-02                 100.0
# 26                    0          NaN         NaN                   NaN
# 27                   80   2014-07-06  2016-01-02                  95.0
# 28                    6   2015-10-24  2016-01-02                 100.0
# 29                    4   2015-01-04  2015-07-25                  85.0
# ...                 ...          ...         ...                   ...
# 3788                 14   2015-09-03  2015-12-20                  99.0
# 3789                 23   2015-02-17  2015-11-28                  90.0
# 3790                 75   2014-05-18  2015-12-14                  98.0
# 3791                 11   2015-08-25  2015-11-28                 100.0
# 3792                  0          NaN         NaN                   NaN
# 3793                 78   2014-07-07  2015-12-30                  98.0
# 3794                 21   2015-06-16  2015-12-15                  90.0
# 3795                 10   2015-04-26  2015-10-24                  98.0
# 3796                233   2012-07-29  2015-12-31                  98.0
# 3797                  1   2016-01-02  2016-01-02                 100.0
# 3798                128   2014-03-31  2015-12-31                  98.0
# 3799                  5   2015-08-16  2015-12-25                  95.0
# 3800                  0          NaN         NaN                   NaN
# 3801                 28   2014-11-21  2015-12-10                 100.0
# 3802                  0          NaN         NaN                   NaN
# 3803                  4   2015-12-14  2016-01-01                  95.0
# 3804                 12   2015-08-04  2015-11-29                  95.0
# 3805                 10   2015-10-21  2015-12-23                  98.0
# 3806                  1   2015-08-31  2015-08-31                 100.0
# 3807                  7   2015-04-12  2015-10-04                  97.0
# 3808                 29   2013-12-10  2015-10-04                  96.0
# 3809                 10   2015-04-26  2015-08-30                  80.0
# 3810                  5   2015-10-01  2015-12-27                  92.0
# 3811                  2   2015-10-01  2015-10-16                 100.0
# 3812                 73   2014-07-08  2015-12-29                  96.0
# 3813                  1   2015-09-27  2015-09-27                  80.0
# 3814                  2   2015-12-18  2015-12-24                 100.0
# 3815                  0          NaN         NaN                   NaN
# 3816                  0          NaN         NaN                   NaN
# 3817                  0          NaN         NaN                   NaN
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                       10.0                       10.0
# 1                       10.0                       10.0
# 2                       10.0                       10.0
# 3                        NaN                        NaN
# 4                        9.0                        9.0
# 5                       10.0                       10.0
# 6                       10.0                       10.0
# 7                       10.0                       10.0
# 8                       10.0                        9.0
# 9                       10.0                       10.0
# 10                      10.0                       10.0
# 11                      10.0                       10.0
# 12                      10.0                       10.0
# 13                      10.0                       10.0
# 14                       9.0                       10.0
# 15                       8.0                       10.0
# 16                      10.0                        9.0
# 17                      10.0                       10.0
# 18                       NaN                        NaN
# 19                      10.0                        9.0
# 20                      10.0                       10.0
# 21                       9.0                        9.0
# 22                      10.0                       10.0
# 23                       NaN                        NaN
# 24                      10.0                       10.0
# 25                      10.0                       10.0
# 26                       NaN                        NaN
# 27                      10.0                       10.0
# 28                      10.0                       10.0
# 29                       8.0                        9.0
# ...                      ...                        ...
# 3788                    10.0                       10.0
# 3789                     9.0                        9.0
# 3790                    10.0                       10.0
# 3791                    10.0                       10.0
# 3792                     NaN                        NaN
# 3793                    10.0                       10.0
# 3794                     9.0                        9.0
# 3795                    10.0                       10.0
# 3796                    10.0                       10.0
# 3797                    10.0                       10.0
# 3798                    10.0                       10.0
# 3799                    10.0                        9.0
# 3800                     NaN                        NaN
# 3801                    10.0                       10.0
# 3802                     NaN                        NaN
# 3803                    10.0                       10.0
# 3804                    10.0                       10.0
# 3805                    10.0                       10.0
# 3806                    10.0                       10.0
# 3807                    10.0                       10.0
# 3808                    10.0                        9.0
# 3809                     8.0                        7.0
# 3810                     9.0                        8.0
# 3811                     9.0                        8.0
# 3812                    10.0                       10.0
# 3813                     8.0                       10.0
# 3814                    10.0                       10.0
# 3815                     NaN                        NaN
# 3816                     NaN                        NaN
# 3817                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      10.0                         10.0
# 1                      10.0                         10.0
# 2                      10.0                         10.0
# 3                       NaN                          NaN
# 4                      10.0                         10.0
# 5                      10.0                         10.0
# 6                      10.0                         10.0
# 7                      10.0                         10.0
# 8                      10.0                          9.0
# 9                      10.0                         10.0
# 10                     10.0                         10.0
# 11                      9.0                         10.0
# 12                     10.0                         10.0
# 13                      9.0                          9.0
# 14                     10.0                         10.0
# 15                      8.0                          8.0
# 16                     10.0                         10.0
# 17                     10.0                         10.0
# 18                      NaN                          NaN
# 19                      9.0                          9.0
# 20                     10.0                         10.0
# 21                      9.0                          9.0
# 22                     10.0                         10.0
# 23                      NaN                          NaN
# 24                     10.0                         10.0
# 25                      9.0                         10.0
# 26                      NaN                          NaN
# 27                     10.0                         10.0
# 28                     10.0                         10.0
# 29                      7.0                         10.0
# ...                     ...                          ...
# 3788                   10.0                         10.0
# 3789                    9.0                         10.0
# 3790                   10.0                         10.0
# 3791                   10.0                         10.0
# 3792                    NaN                          NaN
# 3793                   10.0                         10.0
# 3794                   10.0                         10.0
# 3795                   10.0                         10.0
# 3796                   10.0                         10.0
# 3797                   10.0                         10.0
# 3798                   10.0                         10.0
# 3799                   10.0                         10.0
# 3800                    NaN                          NaN
# 3801                   10.0                         10.0
# 3802                    NaN                          NaN
# 3803                   10.0                         10.0
# 3804                   10.0                         10.0
# 3805                   10.0                         10.0
# 3806                   10.0                         10.0
# 3807                   10.0                         10.0
# 3808                   10.0                         10.0
# 3809                    9.0                          9.0
# 3810                   10.0                         10.0
# 3811                   10.0                         10.0
# 3812                   10.0                         10.0
# 3813                    4.0                          8.0
# 3814                   10.0                         10.0
# 3815                    NaN                          NaN
# 3816                    NaN                          NaN
# 3817                    NaN                          NaN
#
#       review_scores_location  review_scores_value
# 0                        9.0                 10.0
# 1                       10.0                 10.0
# 2                       10.0                 10.0
# 3                        NaN                  NaN
# 4                        9.0                  9.0
# 5                       10.0                 10.0
# 6                       10.0                 10.0
# 7                        9.0                 10.0
# 8                       10.0                 10.0
# 9                       10.0                  9.0
# 10                      10.0                 10.0
# 11                      10.0                  9.0
# 12                      10.0                 10.0
# 13                      10.0                 10.0
# 14                      10.0                 10.0
# 15                       8.0                  8.0
# 16                      10.0                  9.0
# 17                      10.0                 10.0
# 18                       NaN                  NaN
# 19                       8.0                  8.0
# 20                      10.0                 10.0
# 21                      10.0                  8.0
# 22                      10.0                 10.0
# 23                       NaN                  NaN
# 24                      10.0                 10.0
# 25                      10.0                 10.0
# 26                       NaN                  NaN
# 27                       9.0                  9.0
# 28                      10.0                 10.0
# 29                       9.0                  9.0
# ...                      ...                  ...
# 3788                    10.0                 10.0
# 3789                     9.0                  9.0
# 3790                    10.0                 10.0
# 3791                    10.0                 10.0
# 3792                     NaN                  NaN
# 3793                    10.0                 10.0
# 3794                     9.0                  8.0
# 3795                    10.0                 10.0
# 3796                    10.0                 10.0
# 3797                    10.0                 10.0
# 3798                    10.0                 10.0
# 3799                    10.0                 10.0
# 3800                     NaN                  NaN
# 3801                    10.0                 10.0
# 3802                     NaN                  NaN
# 3803                    10.0                 10.0
# 3804                    10.0                 10.0
# 3805                    10.0                 10.0
# 3806                    10.0                 10.0
# 3807                    10.0                  9.0
# 3808                    10.0                  9.0
# 3809                     9.0                  8.0
# 3810                    10.0                  8.0
# 3811                    10.0                 10.0
# 3812                     9.0                 10.0
# 3813                    10.0                  8.0
# 3814                    10.0                 10.0
# 3815                     NaN                  NaN
# 3816                     NaN                  NaN
# 3817                     NaN                  NaN
#
# [3818 rows x 10 columns]

# %%
seattle_listings[seattle_listings['review_scores_accuracy']==2.][['number_of_reviews',
       'first_review', 'last_review', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value']]
# Out:
#       number_of_reviews first_review last_review  review_scores_rating  \
# 1222                  1   2015-12-06  2015-12-06                  20.0
# 2827                  1   2015-11-22  2015-11-22                  80.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 1222                     2.0                        4.0
# 2827                     2.0                        6.0
#
#       review_scores_checkin  review_scores_communication  \
# 1222                    2.0                          2.0
# 2827                    8.0                          8.0
#
#       review_scores_location  review_scores_value
# 1222                     6.0                  2.0
# 2827                    10.0                 10.0

# %%
seattle_calendar=pd.read_csv("seattle/calendar.csv")

# %%
seattle_calendar
# Out:
#          listing_id        date available   price
# 0            241032  2016-01-04         t  $85.00
# 1            241032  2016-01-05         t  $85.00
# 2            241032  2016-01-06         f     NaN
# 3            241032  2016-01-07         f     NaN
# 4            241032  2016-01-08         f     NaN
# 5            241032  2016-01-09         f     NaN
# 6            241032  2016-01-10         f     NaN
# 7            241032  2016-01-11         f     NaN
# 8            241032  2016-01-12         f     NaN
# 9            241032  2016-01-13         t  $85.00
# 10           241032  2016-01-14         t  $85.00
# 11           241032  2016-01-15         f     NaN
# 12           241032  2016-01-16         f     NaN
# 13           241032  2016-01-17         f     NaN
# 14           241032  2016-01-18         t  $85.00
# 15           241032  2016-01-19         t  $85.00
# 16           241032  2016-01-20         t  $85.00
# 17           241032  2016-01-21         f     NaN
# 18           241032  2016-01-22         f     NaN
# 19           241032  2016-01-23         f     NaN
# 20           241032  2016-01-24         t  $85.00
# 21           241032  2016-01-25         t  $85.00
# 22           241032  2016-01-26         t  $85.00
# 23           241032  2016-01-27         t  $85.00
# 24           241032  2016-01-28         t  $85.00
# 25           241032  2016-01-29         f     NaN
# 26           241032  2016-01-30         f     NaN
# 27           241032  2016-01-31         f     NaN
# 28           241032  2016-02-01         t  $85.00
# 29           241032  2016-02-02         t  $85.00
# ...             ...         ...       ...     ...
# 1393540    10208623  2016-12-04         f     NaN
# 1393541    10208623  2016-12-05         f     NaN
# 1393542    10208623  2016-12-06         f     NaN
# 1393543    10208623  2016-12-07         f     NaN
# 1393544    10208623  2016-12-08         f     NaN
# 1393545    10208623  2016-12-09         f     NaN
# 1393546    10208623  2016-12-10         f     NaN
# 1393547    10208623  2016-12-11         f     NaN
# 1393548    10208623  2016-12-12         f     NaN
# 1393549    10208623  2016-12-13         f     NaN
# 1393550    10208623  2016-12-14         f     NaN
# 1393551    10208623  2016-12-15         f     NaN
# 1393552    10208623  2016-12-16         f     NaN
# 1393553    10208623  2016-12-17         f     NaN
# 1393554    10208623  2016-12-18         f     NaN
# 1393555    10208623  2016-12-19         f     NaN
# 1393556    10208623  2016-12-20         f     NaN
# 1393557    10208623  2016-12-21         f     NaN
# 1393558    10208623  2016-12-22         f     NaN
# 1393559    10208623  2016-12-23         f     NaN
# 1393560    10208623  2016-12-24         f     NaN
# 1393561    10208623  2016-12-25         f     NaN
# 1393562    10208623  2016-12-26         f     NaN
# 1393563    10208623  2016-12-27         f     NaN
# 1393564    10208623  2016-12-28         f     NaN
# 1393565    10208623  2016-12-29         f     NaN
# 1393566    10208623  2016-12-30         f     NaN
# 1393567    10208623  2016-12-31         f     NaN
# 1393568    10208623  2017-01-01         f     NaN
# 1393569    10208623  2017-01-02         f     NaN
#
# [1393570 rows x 4 columns]
